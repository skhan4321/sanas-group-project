# %%
import csv
import os 
import pandas as pd

# %%
csvpath = os.path.join("Food_Establishment_Inspection_Scores.csv")
with open(csvpath,'r') as food_data:
    csvreader = csv.reader(food_data) 
    data_frame = pd.DataFrame(csvreader)
    
data_frame
# Out:
#                                             0         1                2  \
# 0                          ï»¿Restaurant Name  Zip Code  Inspection Date
# 1                                  Donn's BBQ     78741       05/14/2018
# 2                    Hayley Cakes and Cookies     78730       03/06/2019
# 3                                Signature #9     78701       06/30/2017
# 4                               Steak n Shake     78748       01/26/2018
# ...                                       ...       ...              ...
# 24854                                Fuel Bar     78759       09/10/2019
# 24855             Dollar General Store #10948     78744       10/11/2018
# 24856                      Child Craft School     78705       03/27/2019
# 24857                                  Subway     78758       05/10/2018
# 24858  Wal-Mart Supercenter Deli/Bakery #5317     78748       08/04/2017
#
#            3                                                  4            5  \
# ...
